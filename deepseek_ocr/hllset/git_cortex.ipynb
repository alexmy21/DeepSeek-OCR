# %%
# In your git_cortex.ipynb
import sys
import os

# Add current directory to path
sys.path.append(os.getcwd())

print("Testing fixed HLLSets implementation...")

# Test 1: Basic HllSet functionality
try:
    from HLLSets import HllSet
    print("✅ HLLSets imported successfully!")
    
    hll = HllSet(p=10)
    hll.add("test_element")
    hll.add("another_element")
    print(f"✅ HllSet count: {hll.count}")
    print(f"✅ HllSet ID: {hll.id}")
    
except Exception as e:
    print(f"❌ HllSet test failed: {e}")
    import traceback
    traceback.print_exc()

# Test 2: Git Cortex integration
print("Testing fixed Git integration...")

try:
    from git_cortex import GitBackedCortex, test_hllset_git_integration
    test_hllset_git_integration()
except Exception as e:
    print(f"❌ Test failed: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Testing fixed HLLSets implementation...
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# juliacall not available, using Python fallback
# ⚠️  Using Python fallback HllSet implementation
# ✅ HLLSets imported successfully!
# ✅ HllSet count: 2
# ✅ HllSet ID: 85ef2a58a3f19e6f072a30efaad82581e3a4f34f
# Testing fixed Git integration...
# ✅ HllSet imported successfully
# Testing HllSet Git integration...
# ✅ GitBackedCortex initialized
# ✅ HllSet created with count: 2
# ✅ HllSet stored with SHA: 6fdc6d06c912979c33a978b463a6632f405226f8
# ✅ HllSet retrieved with count: 2
# ✅ Context created with SHA: 44c51eb3...
# ✅ Context retrieved: test_context
# ✅ Edge created with SHA: aa427584...
# ✅ Edge retrieved: test_edge
# ✅ Contexts: ['test_context']
# ✅ Edges: ['test_edge']
# ✅ History (1 commits)
#    aa427584 - Edge: test_edge (τ=0.8, ρ=0.6)
# 🎉 All tests passed!
