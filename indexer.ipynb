# %%
from deepseek_ocr.shadow_extension import get_cortex_extension

# Initialize the extension
cortex_ext = get_cortex_extension(
    redis_url="redis://localhost:6379",
    git_repo_path="./hllset_cortex_repo"
)
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# juliacall not available, using Python fallback
# ⚠️  Using Python fallback HllSet implementation
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from deepseek_ocr.shadow_extension import get_cortex_extension
#       3 # Initialize the extension
#       4 cortex_ext = get_cortex_extension(
#       5     redis_url="redis://localhost:6379",
#       6     git_repo_path="./hllset_cortex_repo"
#       7 )
#
# File ~/SGS/DeepSeek-OCR/deepseek_ocr/shadow_extension.py:12
#       9 # Add the current directory to path so we can import our modules
#      10 sys.path.insert(0, os.path.dirname(__file__))
# ---> 12 from .hllset_cortex.integration.deepseek_ocr import DeepSeekOCRIntegration
#      14 class DeepSeekOCRWithCortex:
#      15     """
#      16     Wrapper class that adds HLLSet Cortex capabilities to DeepSeek-OCR
#      17     """
#
# File ~/SGS/DeepSeek-OCR/deepseek_ocr/hllset_cortex/integration/deepseek_ocr.py:8
#       5 from ..hi_index.redis_index import RedisHIIndex, HIIndexRecord
#       6 from ..hi_index.synchronizer import HIIndexSynchronizer
# ----> 8 class DeepSeekOCRIntegration:
#       9     """
#      10     Main integration class that connects DeepSeek-OCR with HLLSet Cortex
#      11     """
#      13     def __init__(self,
#      14                  redis_url: str = "redis://localhost:6379",
#      15                  git_repo_path: str = "./hllset_cortex_repo",
#      16                  hllset_config: HLLSetConfig = None):
#
# File ~/SGS/DeepSeek-OCR/deepseek_ocr/hllset_cortex/integration/deepseek_ocr.py:16, in DeepSeekOCRIntegration()
#       8 class DeepSeekOCRIntegration:
#       9     """
#      10     Main integration class that connects DeepSeek-OCR with HLLSet Cortex
#      11     """
#      13     def __init__(self,
#      14                  redis_url: str = "redis://localhost:6379",
#      15                  git_repo_path: str = "./hllset_cortex_repo",
# ---> 16                  hllset_config: HLLSetConfig = None):
#      18         self.hllset_config = hllset_config or HLLSetConfig()
#      20         # Initialize Git Cortex
#
# NameError: name 'HLLSetConfig' is not defined

# %%
# Process a document with cortex
result = cortex_ext.recognize("document.pdf")
print(f"OCR Text: {result['text']}")
print(f"HLLSet SHA: {result['cortex']['hllset_sha']}")
print(f"Similar documents: {len(result['cortex']['similar_documents'])}")

# Query similar documents
similar = cortex_ext.query_similar("quantum physics", max_results=5)
for doc in similar:
    print(f"Similarity: {doc['similarity']:.3f}")
